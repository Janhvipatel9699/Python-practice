# %%
# finding length og the string
# without methods
str=input("Enter the string:")
length=0
for i in str:
    length+=1
print("The length of the string",str," is:",length)
# with methods
print(f"the length of the string is {len(str)}")
# Out:
# The length of the string iljhggtt  is: 8
# the length of the string is 8

# %%
s=input("Enter the string:")
c,k=0,0
print(s)
for i in s:
    if i.isalpha():
        c+=1
    elif i.isalnum():
        k+=1
print(c)
print(k)
# Out:
# sduu8474t=-rjn83
# 8
# 6
