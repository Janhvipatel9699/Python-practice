# %%
# printing positive no. and negative no. of the list containing integers
a = list(map(int, input("Enter numbers: ").split()))
print("List is",a)
print("positive no.")
for i in a:
    if i>=0:
        print(i,end=" ")
print("\nnegative no.")
for i in a:
    if i<0:
        print(i,end=" ")
# Out:
# List is [19]
# positive no.
# 19
# negative no.

# %%
# printing mean of a list 
a = list(map(int, input("Enter numbers: ").split()))
m=0
for i in a:
    m+=i
    k=m/len(a)
print("the mean of the list is",k)
# Out:
# the mean of the list is 2.6666666666666665

# %%
# printing max no. from the list and returning its index
# program without using list functions
a = list(map(int, input("Enter numbers: ").split()))
print(f"The list is{a}")
maxi=a[0]
for i in range(len(a)):
    if a[i]>maxi:
        maxi=a[i]
        index=i
print(f"the max no. in list is {maxi} and its index no. is {index}")

# # program with using list functions
a = list(map(int, input("Enter numbers: ").split()))
max1=max(a)
print(f"The max no. in the list is :{max1}")
print(max)
# Out:
# The max no. in the list is :8
# <built-in function max>

# %%
#  printing second max no. from the list and returning its index
a = list(map(int, input("Enter numbers: ").split()))
print(f"The list is{a}")
maxi=a[0]
max2=a[0]
i1=0
i2=0
for i in range(len(a)):
    if maxi<a[i]:
        max2=maxi
        maxi=a[i]
        i2=i1
        i1=i
    elif max2<a[i] and max!=a[i]:
        max2=a[i]
        i2=i
print("the second maximum no. in the list is",max2,"and its index no.is",i2)

# with using function
p = input("Enter numbers: ").split()

if p:  # check if list is not empty
    l = list(map(int, p))  # convert to integers
    print(l)
    l.remove(max(l))
    c=max(l)
    print(f"The second maximum no. in list is {c} and its index is {l.index(c)}")

else:
    print("No numbers entered!")
# Out:
# [1, 66, 77, 33, 99]
# The second maximum no. in list is 77 and its index is 2

# %%
# printing min and second min no. in the list
# without using function
a = list(map(int, input("Enter numbers: ").split()))
if a[0]>a[1]:
    mini=a[1]
    min1=a[0]
    i3=1
    i1=0
else:
    mini=a[0]
    min1=a[1] 
    i3=0
    i1=1  
for i in range(2,len(a)):
    if mini > a[i]:
        min1=mini
        mini=a[i]
        i1=i3
        i3=i
    elif min1>a[i] and mini!=a[i] :
        min1=a[i]
        i1=i
print("the min no. is",mini,"and index is",i3)
print("the second min no. is",min1,"and index is",i1)

# with using function
p = input("Enter numbers: ").split()

if p:  # check if list is not empty
    l = list(map(int, p))  # convert to integers
    print(l)
    print("the min no. is",min(l),"and index is",l.index(min(l)))
    l.remove(min(l))
    c=min(l)
    print(f"The second minimum no. in list is {c} and its index is {l.index(c)}")

else:
    print("No numbers entered!")

# %%
# check whether a given no. is present in the list or not
a = list(map(int, input("Enter numbers: ").split()))
n=int(input("enter a no." ))
for i in a:
    if i== n:
        print("The no. is present in the list")
    else:
       print("The no. is present in the list")

# %%
# reverse the list

a = list(map(int, input("Enter numbers: ").split()))
l=[]
for i in range(len(a)-1,-1,-1):
    l.append(a[i])      # l+=[a[i]]
print(l) 
#  using string slicing
print(a[::-1])

# %%
# creating list of even and odd no.s
a = list(map(int, input("Enter numbers: ").split()))
l=[]
k=[]
for i in a:
    if i %2==0:
        l.append(i)
    else:
        k.append(i)
print("list of even no.",l )
print("list of odd no.",k)

# %%
# rmoving duplicate elements from a list
a = list(map(int, input("Enter numbers: ").split()))
l=[]
for i in a:
    if i not in l:
        l.append(i)    
print(l)

# %%
# printing how man times a no. is present in the list.
# without using function
a = list(map(int, input("Enter numbers: ").split()))
m=int(input())
q=0
for i in a:
    if i == m:
        q+=1
print(f"{m} is present in the list {q} times")

# with using functions
print(f"{m} is present in the list {a.count(m)} times")

# %%
# check list is palindrome or not
# printing counting of no.s present in the list
f = list(map(int, input("Enter numbers: ").split()))
g=[0,0,3,3,5,0,8,0]
f=g[::-1]
if f == g:
    print("List is palindrome")
else:
    print("List is not palindrome")

# %%
# printing counting of no.s present in the list
g = list(map(int, input("Enter numbers: ").split()))
for i in range(len(g)):
    c=0
    for j in range(len(g)):
        if g[i]==g[j]:
            c+=1
    l=False
    for k in range(i):
        if g[k]==g[i]:
            l=True
    if l== False:
        print(g[i],"=",c)

# %%
# moving all zeroes at the end
g= list(map(int, input("Enter numbers: ").split()))
f=[]
d=[]
for i in range(len(g)):
    if g[i]==0:
        f.append(g[i])
    else:
        d.append(g[i])
print(f,d)
d.extend(f)
print(d)
for i in g:
    if i!=0:
        f.append(i)
for i in g:
    if i == 0:
        f.append(i)
print(f)
